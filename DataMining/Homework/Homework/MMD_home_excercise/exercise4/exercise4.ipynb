# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
X, y = digits["data"], digits["target"]

# %%
from openTSNE import TSNE

embedding = TSNE().fit(X)
# Out:
# /Users/thinhnguyen/opt/anaconda3/lib/python3.7/site-packages/openTSNE/nearest_neighbors.py:184: UserWarning: `pynndescent` has recently changed which distance metrics are supported, and `openTSNE.nearest_neighbors` has not been updated. Please notify the developers of this change.
#   "`pynndescent` has recently changed which distance metrics are supported, "

# %%
embedding[:5]
# Out:
# TSNEEmbedding([[ -2.38728667,  42.4952844 ],
#                [ 10.19425604,  -8.38327032],
#                [ -8.46728884, -17.33198279],
#                [-28.42201871,   4.18405265],
#                [ 33.7817591 ,  -5.71978992]])

# %%
target_ids = range(len(digits.target_names))

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
for i, c, label in zip(target_ids, colors, digits.target_names):
    plt.scatter(embedding[y == i, 0], embedding[y == i, 1], c=c, label=label)
plt.legend()
plt.show()
